# %%
n=10
n2=(n)** 2

print(n2)
# Out:
# 100

# %%
print("andy\nbrown")
# Out:
# andy
# brown

# %%
a=10
b=20
c=a>b
print(not(c))
# Out:
# True

# %%
x=1
y=x
x=2
print(y)
# Out:
# 1

# %%
n=0
if n>0:
  print("*")
elif n ==True:
  print("**")
else:
  print("***")
# Out:
# ***

# %%
n=3
if n>0:
  print("1", end ="")
  if n>=3:
    print("2",end="")
    if n!=3:
      print("3",end="")
    else:
      print("4",end="")
else:
  print("5",end="")
# Out:
# 124

# %%
numbers = [1,2,3,4,5]
nums=numbers[0:-1]
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
numbers=[1,2,3]
mums = numbers[:]
nums.append(4)
print(numbers)
# Out:
# [1, 2, 3]

# %%
numbers = [1,2,[3,[4,5]],6]
for n in numbers:
  print(n)
# Out:
# 1
# 2
# [3, [4, 5]]
# 6

# %%
d={'Adam':189,'John':168,'Mary':172}

for el in d:
  print(el)
# Out:
# Adam
# John
# Mary

# %%
def addnums(x):
  v=3
  print(x+v)
v=6
addnums(2)
# Out:
# 5
